# %% [markdown]
# <a href="https://colab.research.google.com/github/joycechungyt/Stable-diffusion/blob/main/stablediffusiontest2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install together
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 10.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.3.0 which is incompatible.
# ...

# %%
import together
import base64

together.api_key = ""

# generate image
response = together.Image.create(model = 'stabilityai/stable-diffusion-2-1', prompt="Space robots")
# Out:
# <ipython-input-3-48bebd4c85fc>:7: DeprecationWarning: Call to deprecated function create.
#   response = together.Image.create(model = 'stabilityai/stable-diffusion-2-1', prompt="Space robots")
# /usr/local/lib/python3.10/dist-packages/together/legacy/images.py:20: UserWarning: The use of together.api_key is deprecated and will be removed in the next major release. Please set the TOGETHER_API_KEY environment variable instead.
#   warnings.warn(API_KEY_WARNING)

# %%
print(response)
# Out:
# {'id': '870a35d02a49add5-ATL', 'model': 'stabilityai/stable-diffusion-2-1', 'object': 'list', 'data': [{'index': 0, 'b64_json': '...'}]}

# %%
# # save the first image
# image = response["output"]["choices"][0]
# with open("spacerobots.png", "wb") as f:
#     f.write(base64.b64decode(image["image_base64"]))

# %%
import base64

# Get the base64-encoded image data
image_data = response['data'][0]['b64_json']

# Decode the base64-encoded image data
decoded_data = base64.b64decode(image_data)

# Save the image to a file
with open("spacerobots.png", "wb") as f:
    f.write(decoded_data)

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Open and display the image
image = Image.open("spacerobots.png")
plt.imshow(image)
plt.axis('off')
plt.show()
